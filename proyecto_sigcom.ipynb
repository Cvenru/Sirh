# %% [markdown]
# ### Listado de objetivos
#     1.Crear homologación de unidades
#         ejemplo:
#         Alimentación ={SEDILE A, SEDILE B, Sedile,
#                         cedile, Aliment., Alimentación, ...}
#     2.Crear vinculación por subdirecciones y/o direccion
#         ejemplo:
#             Dirección = {CONTROL DE GESTIÓN, AUDITORÍA, CALIDAD,}
#             SDGA = {adyt, uraci, ...}
#             SDGP = {}
#     3.  Apilar registros de sueldos, horas extras, bonificaciones, etc,
#         ejemplo: juan perez, 7123458-7, $1.000.000, enero-2026, $73.540 (hr extra), 25 (hr extra), $150.000 (bonificacion)
#     4.
# ## Posibles extensiones
#     Monitorear cantidad de pagos retroactivos
#     Monitorear Cantidad de días trabajados
#     Costo por unidad
#     Costo por Subdirección
#     Discrepancias entre meses de sueldos bases
#     Costo por nacionalidad
#     Costo por genero
#     Costo por estamento {medico, profesional, tecnico, administrativo, auxiliares}
#     Costo por Ley {15, 18, 19, honorario}+
#     Cantidad de contratos {44,28, 22, 11}
